# %% [markdown]
# # MiniJEPA Training Notebook
# This notebook runs the MiniJEPA training and quick inference workflow.

# %%
# !pip install -r ../requirements.txt

# %%
# !python ../train.py --dataset cifar10 --epochs 5 --batch_size 128 --patch_size 8

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('../outputs/sample_prediction.png')
plt.figure(figsize=(14,4))
plt.imshow(img)
plt.axis('off')
plt.title('MiniJEPA Sample Prediction')
